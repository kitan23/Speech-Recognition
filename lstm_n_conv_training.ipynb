# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import gc
import pickle
import sys

import librosa
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from audiomentations import AddGaussianNoise, Compose, PitchShift, Shift, TimeStretch
from IPython.lib.display import Audio
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    BatchNormalization,
    Bidirectional,
    Conv1D,
    Dense,
    Dropout,
    Flatten,
    Input,
    MaxPool1D,
)
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-05-05 16:59:48.094444: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 16:59:48.121189: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 16:59:48.121213: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 16:59:48.121218: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 16:59:48.125598: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices("GPU")
print(gpus)
tf.config.set_logical_device_configuration(
    gpus[0],
    [tf.config.LogicalDeviceConfiguration(memory_limit=8000)],
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-05 16:59:50.060163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.075287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.077830: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
emotion_list = {
    0: "neutral",
    1: "calm",
    2: "happy",
    3: "sad",
    4: "angry",
    5: "fearful",
    6: "disgusted",
    7: "surprised",
}
RAV = "data/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
dir_list = os.listdir(RAV)
paths = []
for dir in dir_list:
    files = os.listdir(RAV + dir)
    for file in files:
        paths.append(RAV + dir + "/" + file)

path_train, path_test = train_test_split(paths, test_size=0.2)

# %%
augment = Compose(
    [
        AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.002, p=0.5),  # p = 0.5
        TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
        PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
        Shift(p=0.5),
    ]
)

# %%
def get_label(path, emotion_list):
    fileName = os.path.basename(path)
    parts = fileName.split(".")[0].split("-")
    return int(parts[2]) - 1


def process_test_audios(paths):
    batch_features, batch_labels = [], []
    for path in paths:
        audio, sample_rate = librosa.load(path)
        batch_features.append(audio)
        batch_labels.append(get_label(path, emotion_list))
    return batch_features, batch_labels


def audio_generator(file_paths, batch_size):
    while True:
        batch_paths = np.random.choice(a=file_paths, size=batch_size)
        batch_features, batch_labels = [], []

        for path in batch_paths:
            audio, sample_rate = librosa.load(path)
            augmented_audio = augment(samples=audio, sample_rate=sample_rate)
            batch_features.append(augmented_audio)
            batch_labels.append(get_label(path, emotion_list))

        yield batch_features, batch_labels


def extract_mfcc(audio):
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40).T, axis=0)
    return mfccs


def plot_network_history(network_history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    axes[0].plot(network_history.history["loss"], label="Training Loss")
    axes[0].plot(network_history.history["val_loss"], label="Validation Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(network_history.history["accuracy"], label="Training Accuracy")
    axes[1].plot(network_history.history["val_accuracy"], label="Validation Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.show()

# %%
# X_test, Y_test = process_test_audios(path_test)

# batch_size = 24
# gen = audio_generator(file_paths=path_train, batch_size=batch_size)
# X_train, Y_train = [], []
# for i in range(500):
#     batch_data, batch_labels = next(gen)
#     X_train += batch_data
#     Y_train += batch_labels


# Y_train, Y_test = to_categorical(Y_train), to_categorical(Y_test)
# len(X_train), len(Y_train)

# %%
# data = {"X_train_raw": X_train, "X_test_raw": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/raw_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
# with open("./data/raw_data.pickle", "rb") as f:
#     data = pickle.load(f)
# X_train = data["X_train_raw"]
# X_test = data["X_test_raw"]
# Y_train = data["Y_train"]
# Y_test = data["Y_test"]

# %%
# X_train = np.array([extract_mfcc(audio) for audio in X_train])
# X_test = np.array([extract_mfcc(audio) for audio in X_test])
# X_train = np.expand_dims(X_train, -1)
# X_test = np.expand_dims(X_test, -1)

# %%
# data = {"X_train": X_train, "X_test": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/processed_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
with open("./data/processed_data.pickle", "rb") as f:
    data = pickle.load(f)
X_train = data["X_train"]
X_test = data["X_test"]
Y_train = data["Y_train"]
Y_test = data["Y_test"]

# %%
X_train.shape
# Out:
# (12000, 40, 1)

# %%
print(gc.collect())
K.clear_session()

num_classes = len(Y_test[0])
model = Sequential()

layers = [
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    MaxPool1D(pool_size=2, padding="same"),
    Dropout(0.3),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    Dropout(0.3),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    MaxPool1D(pool_size=2, padding="same"),
    Dropout(0.3),
    #
    LSTM(1024),
    #
    Dense(128, activation="relu"),
    BatchNormalization(),
    Dense(num_classes, activation="softmax"),
]

model = tf.keras.Sequential(layers)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.summary()
# Out:
# 51
# 2024-05-05 16:59:50.409128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.409401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.409522: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.462372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.462564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.462691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 16:59:50.462801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8000 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2f:00.0, compute capability: 8.6
# 2024-05-05 16:59:50.472697: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:746] failed to allocate 7.81GiB (8388608000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 38, 200)           800
#
#  batch_normalization (Batch  (None, 38, 200)           800
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 19, 200)           0
#  D)
#
#  dropout (Dropout)           (None, 19, 200)           0
#
#  conv1d_1 (Conv1D)           (None, 17, 200)           120200
#
#  batch_normalization_1 (Bat  (None, 17, 200)           800
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 17, 200)           0
#
#  conv1d_2 (Conv1D)           (None, 15, 200)           120200
#
#  batch_normalization_2 (Bat  (None, 15, 200)           800
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 200)            0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 8, 200)            0
#
#  lstm (LSTM)                 (None, 1024)              5017600
#
#  dense (Dense)               (None, 128)               131200
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 5393944 (20.58 MB)
# Trainable params: 5392488 (20.57 MB)
# Non-trainable params: 1456 (5.69 KB)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", min_delta=0.00005, patience=10, restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)


network_history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[es, lr_scheduler],
)
# Out:
# Epoch 1/100
# 2024-05-05 16:59:54.380002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2024-05-05 16:59:55.323349: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7b12a384a8e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-05 16:59:55.323372: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-05-05 16:59:55.326257: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-05 16:59:55.373466: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 [==============================] - 6s 13ms/step - loss: 1.9353 - accuracy: 0.2636 - val_loss: 2.2152 - val_accuracy: 0.1950 - lr: 0.0010
# Epoch 2/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.7294 - accuracy: 0.3410 - val_loss: 1.7037 - val_accuracy: 0.3683 - lr: 0.0010
# Epoch 3/100
# 150/150 [==============================] - 1s 8ms/step - loss: 1.5973 - accuracy: 0.4000 - val_loss: 1.6427 - val_accuracy: 0.3663 - lr: 0.0010
# Epoch 4/100
# 150/150 [==============================] - 1s 8ms/step - loss: 1.4933 - accuracy: 0.4416 - val_loss: 1.7390 - val_accuracy: 0.3592 - lr: 0.0010
# Epoch 5/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.4061 - accuracy: 0.4732 - val_loss: 1.3794 - val_accuracy: 0.4900 - lr: 0.0010
# Epoch 6/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.3137 - accuracy: 0.5093 - val_loss: 1.2821 - val_accuracy: 0.5329 - lr: 0.0010
# Epoch 7/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.2143 - accuracy: 0.5530 - val_loss: 1.2136 - val_accuracy: 0.5650 - lr: 0.0010
# Epoch 8/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.1098 - accuracy: 0.5951 - val_loss: 1.2001 - val_accuracy: 0.5671 - lr: 0.0010
# Epoch 9/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.0105 - accuracy: 0.6277 - val_loss: 1.0153 - val_accuracy: 0.6433 - lr: 0.0010
# Epoch 10/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.9131 - accuracy: 0.6684 - val_loss: 0.9573 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 11/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.8024 - accuracy: 0.7132 - val_loss: 0.9767 - val_accuracy: 0.6646 - lr: 0.0010
# Epoch 12/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.7103 - accuracy: 0.7487 - val_loss: 0.8587 - val_accuracy: 0.7100 - lr: 0.0010
# Epoch 13/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.6199 - accuracy: 0.7779 - val_loss: 0.7785 - val_accuracy: 0.7325 - lr: 0.0010
# Epoch 14/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.5291 - accuracy: 0.8105 - val_loss: 0.7730 - val_accuracy: 0.7337 - lr: 0.0010
# Epoch 15/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.4533 - accuracy: 0.8401 - val_loss: 0.8038 - val_accuracy: 0.7325 - lr: 0.0010
# Epoch 16/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.3907 - accuracy: 0.8622 - val_loss: 0.7419 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 17/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.3291 - accuracy: 0.8858 - val_loss: 0.7982 - val_accuracy: 0.7538 - lr: 0.0010
# Epoch 18/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.3029 - accuracy: 0.8958 - val_loss: 0.7712 - val_accuracy: 0.7671 - lr: 0.0010
# Epoch 19/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.2620 - accuracy: 0.9090 - val_loss: 0.7682 - val_accuracy: 0.7721 - lr: 0.0010
# Epoch 20/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.2138 - accuracy: 0.9253 - val_loss: 0.7782 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 21/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.2140 - accuracy: 0.9292 - val_loss: 0.7851 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 22/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1762 - accuracy: 0.9404 - val_loss: 0.8234 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 23/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1653 - accuracy: 0.9442 - val_loss: 0.8080 - val_accuracy: 0.7788 - lr: 0.0010
# Epoch 24/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1625 - accuracy: 0.9439 - val_loss: 0.8198 - val_accuracy: 0.7837 - lr: 0.0010
# Epoch 25/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1408 - accuracy: 0.9502 - val_loss: 0.8165 - val_accuracy: 0.7908 - lr: 0.0010
# Epoch 26/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1076 - accuracy: 0.9658 - val_loss: 0.8536 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 27/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1229 - accuracy: 0.9564 - val_loss: 0.9270 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 28/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1117 - accuracy: 0.9619 - val_loss: 0.9084 - val_accuracy: 0.7763 - lr: 0.0010
# Epoch 29/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0931 - accuracy: 0.9690 - val_loss: 0.9701 - val_accuracy: 0.7717 - lr: 0.0010
# Epoch 30/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0996 - accuracy: 0.9665 - val_loss: 0.9096 - val_accuracy: 0.7837 - lr: 0.0010
# Epoch 31/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1079 - accuracy: 0.9629 - val_loss: 0.9406 - val_accuracy: 0.7850 - lr: 0.0010
# Epoch 32/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0958 - accuracy: 0.9654 - val_loss: 0.9092 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 33/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0910 - accuracy: 0.9682 - val_loss: 0.9401 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 34/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0759 - accuracy: 0.9760 - val_loss: 0.9147 - val_accuracy: 0.7925 - lr: 0.0010
# Epoch 35/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0775 - accuracy: 0.9729 - val_loss: 0.9204 - val_accuracy: 0.7892 - lr: 0.0010
# Epoch 36/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0852 - accuracy: 0.9716 - val_loss: 0.9694 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 37/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0762 - accuracy: 0.9768 - val_loss: 0.9342 - val_accuracy: 0.7887 - lr: 0.0010
# Epoch 38/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0725 - accuracy: 0.9761 - val_loss: 0.9381 - val_accuracy: 0.7929 - lr: 0.0010
# Epoch 39/100
# 148/150 [============================>.] - ETA: 0s - loss: 0.0713 - accuracy: 0.9770
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0715 - accuracy: 0.9768 - val_loss: 0.9897 - val_accuracy: 0.7829 - lr: 0.0010
# Epoch 40/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0382 - accuracy: 0.9874 - val_loss: 0.8808 - val_accuracy: 0.8042 - lr: 5.0000e-04
# Epoch 41/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0212 - accuracy: 0.9942 - val_loss: 0.8888 - val_accuracy: 0.8142 - lr: 5.0000e-04
# Epoch 42/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0191 - accuracy: 0.9946 - val_loss: 0.8615 - val_accuracy: 0.8133 - lr: 5.0000e-04
# Epoch 43/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0186 - accuracy: 0.9946 - val_loss: 0.8974 - val_accuracy: 0.8108 - lr: 5.0000e-04
# Epoch 44/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.9951 - val_loss: 0.8713 - val_accuracy: 0.8167 - lr: 5.0000e-04
# Epoch 45/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.8872 - val_accuracy: 0.8117 - lr: 5.0000e-04
# Epoch 46/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.9091 - val_accuracy: 0.8154 - lr: 5.0000e-04
# Epoch 47/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.9192 - val_accuracy: 0.8167 - lr: 5.0000e-04
# Epoch 48/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0159 - accuracy: 0.9957 - val_loss: 0.9541 - val_accuracy: 0.8046 - lr: 5.0000e-04
# Epoch 49/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.9383 - val_accuracy: 0.8054 - lr: 5.0000e-04
# Epoch 50/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0190 - accuracy: 0.9932 - val_loss: 0.9745 - val_accuracy: 0.8021 - lr: 5.0000e-04
# Epoch 51/100
# 148/150 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9940
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 0.9517 - val_accuracy: 0.8150 - lr: 5.0000e-04
# Epoch 52/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.9295 - val_accuracy: 0.8167 - lr: 2.5000e-04
# Epoch 53/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.9418 - val_accuracy: 0.8150 - lr: 2.5000e-04
# Epoch 54/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.9616 - val_accuracy: 0.8104 - lr: 2.5000e-04

# %%
plot_network_history(network_history)

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
preds = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 1.8147 - accuracy: 0.6528
# 9/9 [==============================] - 0s 2ms/step

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)
y_true = np.argmax(Y_test, 1)

print("Test accuracy: %g" % (accuracy_score(y_true, y_pred)))
print("Precision", precision_score(y_true, y_pred, average="macro"))
print("Recall", recall_score(y_true, y_pred, average="macro"))
print("f1_score", f1_score(y_true, y_pred, average="macro"))
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Test accuracy: 0.652778
# Precision 0.647802298659862
# Recall 0.6503665321093801
# f1_score 0.6456513341252211

# %%
plt.figure(figsize=(8, 4))
conf = confusion_matrix(y_true, y_pred)
labels = emotion_list.values()
sns.heatmap(conf, annot=True, fmt="d", vmax=20, xticklabels=labels, yticklabels=labels)
plt.show()
