# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import gc
import pickle
import sys

import librosa
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from audiomentations import AddGaussianNoise, Compose, PitchShift, Shift, TimeStretch
from IPython.lib.display import Audio
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    BatchNormalization,
    Bidirectional,
    Conv1D,
    Dense,
    Dropout,
    Flatten,
    Input,
    MaxPool1D,
)
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-05-05 17:12:17.426823: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 17:12:17.453466: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 17:12:17.453491: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 17:12:17.453497: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 17:12:17.457603: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices("GPU")
print(gpus)
tf.config.set_logical_device_configuration(
    gpus[0],
    [tf.config.LogicalDeviceConfiguration(memory_limit=8000)],
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-05 17:12:19.498318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:19.512890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:19.517576: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
emotion_list = {
    0: "neutral",
    1: "calm",
    2: "happy",
    3: "sad",
    4: "angry",
    5: "fearful",
    6: "disgusted",
    7: "surprised",
}
RAV = "data/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
dir_list = os.listdir(RAV)
paths = []
for dir in dir_list:
    files = os.listdir(RAV + dir)
    for file in files:
        paths.append(RAV + dir + "/" + file)

path_train, path_test = train_test_split(paths, test_size=0.2)

# %%
augment = Compose(
    [
        AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.002, p=0.5),  # p = 0.5
        TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
        PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
        Shift(p=0.5),
    ]
)

# %%
def get_label(path, emotion_list):
    fileName = os.path.basename(path)
    parts = fileName.split(".")[0].split("-")
    return int(parts[2]) - 1


def process_test_audios(paths):
    batch_features, batch_labels = [], []
    for path in paths:
        audio, sample_rate = librosa.load(path)
        batch_features.append(audio)
        batch_labels.append(get_label(path, emotion_list))
    return batch_features, batch_labels


def audio_generator(file_paths, batch_size):
    while True:
        batch_paths = np.random.choice(a=file_paths, size=batch_size)
        batch_features, batch_labels = [], []

        for path in batch_paths:
            audio, sample_rate = librosa.load(path)
            augmented_audio = augment(samples=audio, sample_rate=sample_rate)
            batch_features.append(augmented_audio)
            batch_labels.append(get_label(path, emotion_list))

        yield batch_features, batch_labels


def extract_mfcc(audio):
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40).T, axis=0)
    return mfccs


def plot_network_history(network_history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    axes[0].plot(network_history.history["loss"], label="Training Loss")
    axes[0].plot(network_history.history["val_loss"], label="Validation Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(network_history.history["categorical_accuracy"], label="Training Categorical Accuracy")
    axes[1].plot(network_history.history["val_categorical_accuracy"], label="Validation Categorical Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.show()

# %%
# X_test, Y_test = process_test_audios(path_test)

# batch_size = 24
# gen = audio_generator(file_paths=path_train, batch_size=batch_size)
# X_train, Y_train = [], []
# for i in range(500):
#     batch_data, batch_labels = next(gen)
#     X_train += batch_data
#     Y_train += batch_labels


# Y_train, Y_test = to_categorical(Y_train), to_categorical(Y_test)
# len(X_train), len(Y_train)

# %%
# data = {"X_train_raw": X_train, "X_test_raw": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/raw_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
# with open("./data/raw_data.pickle", "rb") as f:
#     data = pickle.load(f)
# X_train = data["X_train_raw"]
# X_test = data["X_test_raw"]
# Y_train = data["Y_train"]
# Y_test = data["Y_test"]

# %%
# X_train = np.array([extract_mfcc(audio) for audio in X_train])
# X_test = np.array([extract_mfcc(audio) for audio in X_test])
# X_train = np.expand_dims(X_train, -1)
# X_test = np.expand_dims(X_test, -1)

# %%
# data = {"X_train": X_train, "X_test": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/processed_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
with open("./data/processed_data.pickle", "rb") as f:
    data = pickle.load(f)
X_train = data["X_train"]
X_test = data["X_test"]
Y_train = data["Y_train"]
Y_test = data["Y_test"]

# %%
X_train.shape
# Out:
# (12000, 40, 1)

# %%
print(gc.collect())
K.clear_session()

num_classes = len(Y_test[0])
model = Sequential()

layers = [
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    MaxPool1D(pool_size=2, padding="same"),
    Dropout(0.3),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    Dropout(0.3),
    #
    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    MaxPool1D(pool_size=2, padding="same"),
    Dropout(0.3),
    #
    LSTM(1024),
    #
    Dense(128, activation="relu"),
    BatchNormalization(),
    Dense(num_classes, activation="softmax"),
]

model = tf.keras.Sequential(layers)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["categorical_accuracy"])

model.summary()
# Out:
# 47
# 2024-05-05 17:12:19.943822: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:19.944074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:19.944194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:20.001235: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:20.001459: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:20.001587: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:12:20.001697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8000 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2f:00.0, compute capability: 8.6
# 2024-05-05 17:12:20.011264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:746] failed to allocate 7.81GiB (8388608000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 38, 200)           800
#
#  batch_normalization (Batch  (None, 38, 200)           800
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 19, 200)           0
#  D)
#
#  dropout (Dropout)           (None, 19, 200)           0
#
#  conv1d_1 (Conv1D)           (None, 17, 200)           120200
#
#  batch_normalization_1 (Bat  (None, 17, 200)           800
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 17, 200)           0
#
#  conv1d_2 (Conv1D)           (None, 15, 200)           120200
#
#  batch_normalization_2 (Bat  (None, 15, 200)           800
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 200)            0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 8, 200)            0
#
#  lstm (LSTM)                 (None, 1024)              5017600
#
#  dense (Dense)               (None, 128)               131200
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 5393944 (20.58 MB)
# Trainable params: 5392488 (20.57 MB)
# Non-trainable params: 1456 (5.69 KB)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_categorical_accuracy", min_delta=0.00005, patience=10, restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_categorical_accuracy",
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)


network_history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[es, lr_scheduler],
)
# Out:
# Epoch 1/100
# 2024-05-05 17:12:24.143497: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2024-05-05 17:12:25.092193: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x79908138a3a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-05 17:12:25.092216: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-05-05 17:12:25.095255: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-05 17:12:25.141660: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 [==============================] - 7s 13ms/step - loss: 1.9176 - categorical_accuracy: 0.2713 - val_loss: 1.9156 - val_categorical_accuracy: 0.2925 - lr: 0.0010
# Epoch 2/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.6815 - categorical_accuracy: 0.3684 - val_loss: 1.5375 - val_categorical_accuracy: 0.4200 - lr: 0.0010
# Epoch 3/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.5634 - categorical_accuracy: 0.4124 - val_loss: 1.6434 - val_categorical_accuracy: 0.4075 - lr: 0.0010
# Epoch 4/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.4552 - categorical_accuracy: 0.4615 - val_loss: 1.4995 - val_categorical_accuracy: 0.4750 - lr: 0.0010
# Epoch 5/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.3705 - categorical_accuracy: 0.4880 - val_loss: 1.3329 - val_categorical_accuracy: 0.5067 - lr: 0.0010
# Epoch 6/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.2742 - categorical_accuracy: 0.5257 - val_loss: 1.3965 - val_categorical_accuracy: 0.4558 - lr: 0.0010
# Epoch 7/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.1899 - categorical_accuracy: 0.5595 - val_loss: 1.3297 - val_categorical_accuracy: 0.5417 - lr: 0.0010
# Epoch 8/100
# 150/150 [==============================] - 1s 9ms/step - loss: 1.0929 - categorical_accuracy: 0.5966 - val_loss: 1.1213 - val_categorical_accuracy: 0.5896 - lr: 0.0010
# Epoch 9/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.9779 - categorical_accuracy: 0.6419 - val_loss: 1.0877 - val_categorical_accuracy: 0.6217 - lr: 0.0010
# Epoch 10/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.8924 - categorical_accuracy: 0.6748 - val_loss: 0.9322 - val_categorical_accuracy: 0.6729 - lr: 0.0010
# Epoch 11/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.7693 - categorical_accuracy: 0.7236 - val_loss: 0.8896 - val_categorical_accuracy: 0.6850 - lr: 0.0010
# Epoch 12/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.6912 - categorical_accuracy: 0.7494 - val_loss: 0.9202 - val_categorical_accuracy: 0.6787 - lr: 0.0010
# Epoch 13/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.6233 - categorical_accuracy: 0.7749 - val_loss: 0.8128 - val_categorical_accuracy: 0.7321 - lr: 0.0010
# Epoch 14/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.5371 - categorical_accuracy: 0.8101 - val_loss: 0.7717 - val_categorical_accuracy: 0.7267 - lr: 0.0010
# Epoch 15/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.4638 - categorical_accuracy: 0.8357 - val_loss: 0.7746 - val_categorical_accuracy: 0.7563 - lr: 0.0010
# Epoch 16/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.4044 - categorical_accuracy: 0.8561 - val_loss: 0.7103 - val_categorical_accuracy: 0.7767 - lr: 0.0010
# Epoch 17/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.3553 - categorical_accuracy: 0.8727 - val_loss: 0.7538 - val_categorical_accuracy: 0.7654 - lr: 0.0010
# Epoch 18/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.2995 - categorical_accuracy: 0.8924 - val_loss: 0.6832 - val_categorical_accuracy: 0.7879 - lr: 0.0010
# Epoch 19/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.2580 - categorical_accuracy: 0.9128 - val_loss: 0.7568 - val_categorical_accuracy: 0.7875 - lr: 0.0010
# Epoch 20/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.2425 - categorical_accuracy: 0.9170 - val_loss: 0.7756 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 21/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.2092 - categorical_accuracy: 0.9266 - val_loss: 0.7643 - val_categorical_accuracy: 0.7929 - lr: 0.0010
# Epoch 22/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1836 - categorical_accuracy: 0.9373 - val_loss: 0.7623 - val_categorical_accuracy: 0.7967 - lr: 0.0010
# Epoch 23/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1762 - categorical_accuracy: 0.9389 - val_loss: 0.8219 - val_categorical_accuracy: 0.7804 - lr: 0.0010
# Epoch 24/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1680 - categorical_accuracy: 0.9422 - val_loss: 0.7841 - val_categorical_accuracy: 0.7962 - lr: 0.0010
# Epoch 25/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1367 - categorical_accuracy: 0.9521 - val_loss: 0.8674 - val_categorical_accuracy: 0.7896 - lr: 0.0010
# Epoch 26/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1504 - categorical_accuracy: 0.9480 - val_loss: 0.7953 - val_categorical_accuracy: 0.7967 - lr: 0.0010
# Epoch 27/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1371 - categorical_accuracy: 0.9502 - val_loss: 0.8805 - val_categorical_accuracy: 0.7850 - lr: 0.0010
# Epoch 28/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1058 - categorical_accuracy: 0.9623 - val_loss: 0.9031 - val_categorical_accuracy: 0.7962 - lr: 0.0010
# Epoch 29/100
# 147/150 [============================>.] - ETA: 0s - loss: 0.1027 - categorical_accuracy: 0.9645
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 150/150 [==============================] - 1s 9ms/step - loss: 0.1038 - categorical_accuracy: 0.9639 - val_loss: 0.8735 - val_categorical_accuracy: 0.7850 - lr: 0.0010
# Epoch 30/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0687 - categorical_accuracy: 0.9776 - val_loss: 0.7956 - val_categorical_accuracy: 0.8067 - lr: 5.0000e-04
# Epoch 31/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0407 - categorical_accuracy: 0.9867 - val_loss: 0.7880 - val_categorical_accuracy: 0.8121 - lr: 5.0000e-04
# Epoch 32/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0358 - categorical_accuracy: 0.9896 - val_loss: 0.7854 - val_categorical_accuracy: 0.8204 - lr: 5.0000e-04
# Epoch 33/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0280 - categorical_accuracy: 0.9919 - val_loss: 0.7923 - val_categorical_accuracy: 0.8158 - lr: 5.0000e-04
# Epoch 34/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0280 - categorical_accuracy: 0.9922 - val_loss: 0.7956 - val_categorical_accuracy: 0.8246 - lr: 5.0000e-04
# Epoch 35/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0235 - categorical_accuracy: 0.9929 - val_loss: 0.7920 - val_categorical_accuracy: 0.8200 - lr: 5.0000e-04
# Epoch 36/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0248 - categorical_accuracy: 0.9931 - val_loss: 0.8376 - val_categorical_accuracy: 0.8142 - lr: 5.0000e-04
# Epoch 37/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0233 - categorical_accuracy: 0.9937 - val_loss: 0.8127 - val_categorical_accuracy: 0.8221 - lr: 5.0000e-04
# Epoch 38/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0288 - categorical_accuracy: 0.9916 - val_loss: 0.8861 - val_categorical_accuracy: 0.8158 - lr: 5.0000e-04
# Epoch 39/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0286 - categorical_accuracy: 0.9899 - val_loss: 0.8848 - val_categorical_accuracy: 0.8204 - lr: 5.0000e-04
# Epoch 40/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0333 - categorical_accuracy: 0.9897 - val_loss: 0.9146 - val_categorical_accuracy: 0.8100 - lr: 5.0000e-04
# Epoch 41/100
# 148/150 [============================>.] - ETA: 0s - loss: 0.0345 - categorical_accuracy: 0.9886
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0351 - categorical_accuracy: 0.9883 - val_loss: 0.9059 - val_categorical_accuracy: 0.8108 - lr: 5.0000e-04
# Epoch 42/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0224 - categorical_accuracy: 0.9936 - val_loss: 0.8510 - val_categorical_accuracy: 0.8254 - lr: 2.5000e-04
# Epoch 43/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0148 - categorical_accuracy: 0.9952 - val_loss: 0.8614 - val_categorical_accuracy: 0.8254 - lr: 2.5000e-04
# Epoch 44/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0134 - categorical_accuracy: 0.9962 - val_loss: 0.8705 - val_categorical_accuracy: 0.8192 - lr: 2.5000e-04
# Epoch 45/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0152 - categorical_accuracy: 0.9956 - val_loss: 0.8783 - val_categorical_accuracy: 0.8146 - lr: 2.5000e-04
# Epoch 46/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0120 - categorical_accuracy: 0.9962 - val_loss: 0.8653 - val_categorical_accuracy: 0.8204 - lr: 2.5000e-04
# Epoch 47/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0104 - categorical_accuracy: 0.9973 - val_loss: 0.8640 - val_categorical_accuracy: 0.8208 - lr: 2.5000e-04
# Epoch 48/100
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0102 - categorical_accuracy: 0.9972 - val_loss: 0.8703 - val_categorical_accuracy: 0.8225 - lr: 2.5000e-04
# Epoch 49/100
# 148/150 [============================>.] - ETA: 0s - loss: 0.0081 - categorical_accuracy: 0.9980
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0081 - categorical_accuracy: 0.9980 - val_loss: 0.9045 - val_categorical_accuracy: 0.8167 - lr: 2.5000e-04
# Epoch 50/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0104 - categorical_accuracy: 0.9971 - val_loss: 0.8790 - val_categorical_accuracy: 0.8229 - lr: 1.2500e-04
# Epoch 51/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0080 - categorical_accuracy: 0.9977 - val_loss: 0.8811 - val_categorical_accuracy: 0.8254 - lr: 1.2500e-04
# Epoch 52/100
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0079 - categorical_accuracy: 0.9978 - val_loss: 0.8915 - val_categorical_accuracy: 0.8246 - lr: 1.2500e-04

# %%
plot_network_history(network_history)

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
preds = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 1.8323 - categorical_accuracy: 0.6493
# 9/9 [==============================] - 0s 2ms/step

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)
y_true = np.argmax(Y_test, 1)

print("Test accuracy: %g" % (accuracy_score(y_true, y_pred)))
print("Precision", precision_score(y_true, y_pred, average="macro"))
print("Recall", recall_score(y_true, y_pred, average="macro"))
print("f1_score", f1_score(y_true, y_pred, average="macro"))
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Test accuracy: 0.649306
# Precision 0.6435464367529584
# Recall 0.6431398605826673
# f1_score 0.6358400042042285

# %%
plt.figure(figsize=(8, 4))
conf = confusion_matrix(y_true, y_pred)
labels = emotion_list.values()
sns.heatmap(conf, annot=True, fmt="d", vmax=20, xticklabels=labels, yticklabels=labels)
plt.show()
