# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import gc
import pickle
import sys

import librosa
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from audiomentations import AddGaussianNoise, Compose, PitchShift, Shift, TimeStretch
from IPython.lib.display import Audio
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    BatchNormalization,
    Bidirectional,
    Conv1D,
    Dense,
    Dropout,
    Flatten,
    Input,
    MaxPool1D,
)
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-05-05 17:15:34.346068: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 17:15:34.372131: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 17:15:34.372156: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 17:15:34.372163: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 17:15:34.376468: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices("GPU")
print(gpus)
tf.config.set_logical_device_configuration(
    gpus[0],
    [tf.config.LogicalDeviceConfiguration(memory_limit=8000)],
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-05 17:15:36.398448: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.414041: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.415605: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
emotion_list = {
    0: "neutral",
    1: "calm",
    2: "happy",
    3: "sad",
    4: "angry",
    5: "fearful",
    6: "disgusted",
    7: "surprised",
}
RAV = "data/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
dir_list = os.listdir(RAV)
paths = []
for dir in dir_list:
    files = os.listdir(RAV + dir)
    for file in files:
        paths.append(RAV + dir + "/" + file)

path_train, path_test = train_test_split(paths, test_size=0.2)

# %%
augment = Compose(
    [
        AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.002, p=0.5),  # p = 0.5
        TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
        PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
        Shift(p=0.5),
    ]
)

# %%
def get_label(path, emotion_list):
    fileName = os.path.basename(path)
    parts = fileName.split(".")[0].split("-")
    return int(parts[2]) - 1


def process_test_audios(paths):
    batch_features, batch_labels = [], []
    for path in paths:
        audio, sample_rate = librosa.load(path)
        batch_features.append(audio)
        batch_labels.append(get_label(path, emotion_list))
    return batch_features, batch_labels


def audio_generator(file_paths, batch_size):
    while True:
        batch_paths = np.random.choice(a=file_paths, size=batch_size)
        batch_features, batch_labels = [], []

        for path in batch_paths:
            audio, sample_rate = librosa.load(path)
            augmented_audio = augment(samples=audio, sample_rate=sample_rate)
            batch_features.append(augmented_audio)
            batch_labels.append(get_label(path, emotion_list))

        yield batch_features, batch_labels


def extract_mfcc(audio):
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40).T, axis=0)
    return mfccs


def plot_network_history(network_history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    axes[0].plot(network_history.history["loss"], label="Training Loss")
    axes[0].plot(network_history.history["val_loss"], label="Validation Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(network_history.history["categorical_accuracy"], label="Training Categorical Accuracy")
    axes[1].plot(network_history.history["val_categorical_accuracy"], label="Validation Categorical Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.show()

# %%
# X_test, Y_test = process_test_audios(path_test)

# batch_size = 24
# gen = audio_generator(file_paths=path_train, batch_size=batch_size)
# X_train, Y_train = [], []
# for i in range(500):
#     batch_data, batch_labels = next(gen)
#     X_train += batch_data
#     Y_train += batch_labels


# Y_train, Y_test = to_categorical(Y_train), to_categorical(Y_test)
# len(X_train), len(Y_train)

# %%
# data = {"X_train_raw": X_train, "X_test_raw": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/raw_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
# with open("./data/raw_data.pickle", "rb") as f:
#     data = pickle.load(f)
# X_train = data["X_train_raw"]
# X_test = data["X_test_raw"]
# Y_train = data["Y_train"]
# Y_test = data["Y_test"]

# %%
# X_train = np.array([extract_mfcc(audio) for audio in X_train])
# X_test = np.array([extract_mfcc(audio) for audio in X_test])
# X_train = np.expand_dims(X_train, -1)
# X_test = np.expand_dims(X_test, -1)

# %%
# data = {"X_train": X_train, "X_test": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/processed_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
with open("./data/processed_data.pickle", "rb") as f:
    data = pickle.load(f)
X_train = data["X_train"]
X_test = data["X_test"]
Y_train = data["Y_train"]
Y_test = data["Y_test"]

# %%
X_train.shape
# Out:
# (12000, 40, 1)

# %%
print(gc.collect())
K.clear_session()

num_classes = len(Y_test[0])
model = Sequential()

layers = [
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(1024),
    Dense(num_classes, activation="softmax"),
]

model = tf.keras.Sequential(layers)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["categorical_accuracy"])

model.summary()
# Out:
# 51
# 2024-05-05 17:15:36.833362: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.833628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.833749: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.884331: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.884531: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.884657: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:15:36.884767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8000 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2f:00.0, compute capability: 8.6
# 2024-05-05 17:15:36.894609: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:746] failed to allocate 7.81GiB (8388608000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1024)              4202496
#
#  dense (Dense)               (None, 8)                 8200
#
# =================================================================
# Total params: 4210696 (16.06 MB)
# Trainable params: 4210696 (16.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_categorical_accuracy", min_delta=0.00005, patience=10, restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_categorical_accuracy",
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)


network_history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[es, lr_scheduler],
)
# Out:
# Epoch 1/100
#   1/150 [..............................] - ETA: 3:26 - loss: 2.0851 - categorical_accuracy: 0.0312
# 2024-05-05 17:15:39.526991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2024-05-05 17:15:39.574398: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7e46094f5490 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-05 17:15:39.574428: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-05-05 17:15:39.579013: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-05 17:15:39.646751: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 [==============================] - 4s 18ms/step - loss: 1.9521 - categorical_accuracy: 0.2292 - val_loss: 1.8214 - val_categorical_accuracy: 0.2817 - lr: 0.0010
# Epoch 2/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.8377 - categorical_accuracy: 0.2889 - val_loss: 1.7519 - val_categorical_accuracy: 0.3104 - lr: 0.0010
# Epoch 3/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.7256 - categorical_accuracy: 0.3326 - val_loss: 1.6493 - val_categorical_accuracy: 0.3679 - lr: 0.0010
# Epoch 4/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.6470 - categorical_accuracy: 0.3672 - val_loss: 1.6845 - val_categorical_accuracy: 0.3550 - lr: 0.0010
# Epoch 5/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.5907 - categorical_accuracy: 0.3903 - val_loss: 1.5726 - val_categorical_accuracy: 0.4054 - lr: 0.0010
# Epoch 6/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.5361 - categorical_accuracy: 0.4096 - val_loss: 1.5215 - val_categorical_accuracy: 0.4242 - lr: 0.0010
# Epoch 7/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4754 - categorical_accuracy: 0.4397 - val_loss: 1.4900 - val_categorical_accuracy: 0.4342 - lr: 0.0010
# Epoch 8/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4001 - categorical_accuracy: 0.4701 - val_loss: 1.4046 - val_categorical_accuracy: 0.4787 - lr: 0.0010
# Epoch 9/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3321 - categorical_accuracy: 0.5006 - val_loss: 1.4004 - val_categorical_accuracy: 0.4775 - lr: 0.0010
# Epoch 10/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.2479 - categorical_accuracy: 0.5309 - val_loss: 1.3386 - val_categorical_accuracy: 0.4913 - lr: 0.0010
# Epoch 11/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.1740 - categorical_accuracy: 0.5596 - val_loss: 1.2229 - val_categorical_accuracy: 0.5312 - lr: 0.0010
# Epoch 12/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.0707 - categorical_accuracy: 0.6066 - val_loss: 1.2788 - val_categorical_accuracy: 0.5375 - lr: 0.0010
# Epoch 13/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.9814 - categorical_accuracy: 0.6383 - val_loss: 1.1499 - val_categorical_accuracy: 0.5783 - lr: 0.0010
# Epoch 14/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.9263 - categorical_accuracy: 0.6569 - val_loss: 1.0565 - val_categorical_accuracy: 0.6212 - lr: 0.0010
# Epoch 15/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.8027 - categorical_accuracy: 0.7126 - val_loss: 1.0099 - val_categorical_accuracy: 0.6517 - lr: 0.0010
# Epoch 16/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.7112 - categorical_accuracy: 0.7458 - val_loss: 0.9969 - val_categorical_accuracy: 0.6454 - lr: 0.0010
# Epoch 17/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.6182 - categorical_accuracy: 0.7772 - val_loss: 1.0095 - val_categorical_accuracy: 0.6729 - lr: 0.0010
# Epoch 18/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.5644 - categorical_accuracy: 0.7982 - val_loss: 1.0118 - val_categorical_accuracy: 0.6567 - lr: 0.0010
# Epoch 19/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.4844 - categorical_accuracy: 0.8260 - val_loss: 1.0176 - val_categorical_accuracy: 0.6817 - lr: 0.0010
# Epoch 20/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.4022 - categorical_accuracy: 0.8577 - val_loss: 0.9647 - val_categorical_accuracy: 0.6963 - lr: 0.0010
# Epoch 21/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.3452 - categorical_accuracy: 0.8791 - val_loss: 0.9759 - val_categorical_accuracy: 0.7104 - lr: 0.0010
# Epoch 22/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.3266 - categorical_accuracy: 0.8867 - val_loss: 0.9044 - val_categorical_accuracy: 0.7312 - lr: 0.0010
# Epoch 23/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2678 - categorical_accuracy: 0.9085 - val_loss: 0.9103 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 24/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2517 - categorical_accuracy: 0.9150 - val_loss: 0.9510 - val_categorical_accuracy: 0.7367 - lr: 0.0010
# Epoch 25/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2432 - categorical_accuracy: 0.9154 - val_loss: 0.9288 - val_categorical_accuracy: 0.7308 - lr: 0.0010
# Epoch 26/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1610 - categorical_accuracy: 0.9482 - val_loss: 1.0157 - val_categorical_accuracy: 0.7350 - lr: 0.0010
# Epoch 27/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1732 - categorical_accuracy: 0.9438 - val_loss: 1.0383 - val_categorical_accuracy: 0.7287 - lr: 0.0010
# Epoch 28/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1729 - categorical_accuracy: 0.9452 - val_loss: 1.0077 - val_categorical_accuracy: 0.7321 - lr: 0.0010
# Epoch 29/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1187 - categorical_accuracy: 0.9632 - val_loss: 1.0219 - val_categorical_accuracy: 0.7471 - lr: 0.0010
# Epoch 30/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1131 - categorical_accuracy: 0.9620 - val_loss: 1.1415 - val_categorical_accuracy: 0.7208 - lr: 0.0010
# Epoch 31/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1184 - categorical_accuracy: 0.9626 - val_loss: 1.0561 - val_categorical_accuracy: 0.7308 - lr: 0.0010
# Epoch 32/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0799 - categorical_accuracy: 0.9771 - val_loss: 1.1935 - val_categorical_accuracy: 0.7217 - lr: 0.0010
# Epoch 33/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1280 - categorical_accuracy: 0.9579 - val_loss: 1.1168 - val_categorical_accuracy: 0.7283 - lr: 0.0010
# Epoch 34/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1065 - categorical_accuracy: 0.9690 - val_loss: 1.1267 - val_categorical_accuracy: 0.7233 - lr: 0.0010
# Epoch 35/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0732 - categorical_accuracy: 0.9787 - val_loss: 1.0887 - val_categorical_accuracy: 0.7504 - lr: 0.0010
# Epoch 36/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0364 - categorical_accuracy: 0.9905 - val_loss: 1.1543 - val_categorical_accuracy: 0.7538 - lr: 0.0010
# Epoch 37/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0472 - categorical_accuracy: 0.9865 - val_loss: 1.1353 - val_categorical_accuracy: 0.7517 - lr: 0.0010
# Epoch 38/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1052 - categorical_accuracy: 0.9652 - val_loss: 1.2351 - val_categorical_accuracy: 0.7175 - lr: 0.0010
# Epoch 39/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1097 - categorical_accuracy: 0.9669 - val_loss: 1.1225 - val_categorical_accuracy: 0.7242 - lr: 0.0010
# Epoch 40/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0988 - categorical_accuracy: 0.9681 - val_loss: 1.1048 - val_categorical_accuracy: 0.7517 - lr: 0.0010
# Epoch 41/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0592 - categorical_accuracy: 0.9834 - val_loss: 1.1083 - val_categorical_accuracy: 0.7483 - lr: 0.0010
# Epoch 42/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0389 - categorical_accuracy: 0.9896 - val_loss: 1.1546 - val_categorical_accuracy: 0.7404 - lr: 0.0010
# Epoch 43/100
# 149/150 [============================>.] - ETA: 0s - loss: 0.0477 - categorical_accuracy: 0.9873
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0485 - categorical_accuracy: 0.9872 - val_loss: 1.4283 - val_categorical_accuracy: 0.7183 - lr: 0.0010
# Epoch 44/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0282 - categorical_accuracy: 0.9928 - val_loss: 1.1235 - val_categorical_accuracy: 0.7617 - lr: 5.0000e-04
# Epoch 45/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0058 - categorical_accuracy: 0.9995 - val_loss: 1.1368 - val_categorical_accuracy: 0.7658 - lr: 5.0000e-04
# Epoch 46/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 1.1573 - val_categorical_accuracy: 0.7679 - lr: 5.0000e-04
# Epoch 47/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 1.1769 - val_categorical_accuracy: 0.7692 - lr: 5.0000e-04
# Epoch 48/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 1.1907 - val_categorical_accuracy: 0.7708 - lr: 5.0000e-04
# Epoch 49/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 1.2065 - val_categorical_accuracy: 0.7704 - lr: 5.0000e-04
# Epoch 50/100
# 150/150 [==============================] - 2s 15ms/step - loss: 8.7681e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2180 - val_categorical_accuracy: 0.7688 - lr: 5.0000e-04
# Epoch 51/100
# 150/150 [==============================] - 2s 15ms/step - loss: 8.7076e-04 - categorical_accuracy: 0.9999 - val_loss: 1.2283 - val_categorical_accuracy: 0.7721 - lr: 5.0000e-04
# Epoch 52/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0014 - categorical_accuracy: 0.9998 - val_loss: 1.2039 - val_categorical_accuracy: 0.7750 - lr: 5.0000e-04
# Epoch 53/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0086 - categorical_accuracy: 0.9975 - val_loss: 1.2336 - val_categorical_accuracy: 0.7642 - lr: 5.0000e-04
# Epoch 54/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0028 - categorical_accuracy: 0.9995 - val_loss: 1.2418 - val_categorical_accuracy: 0.7704 - lr: 5.0000e-04
# Epoch 55/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0043 - categorical_accuracy: 0.9992 - val_loss: 1.2504 - val_categorical_accuracy: 0.7696 - lr: 5.0000e-04
# Epoch 56/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0116 - categorical_accuracy: 0.9966 - val_loss: 1.2419 - val_categorical_accuracy: 0.7713 - lr: 5.0000e-04
# Epoch 57/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0151 - categorical_accuracy: 0.9961 - val_loss: 1.4694 - val_categorical_accuracy: 0.7387 - lr: 5.0000e-04
# Epoch 58/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0560 - categorical_accuracy: 0.9823 - val_loss: 1.3385 - val_categorical_accuracy: 0.7104 - lr: 5.0000e-04
# Epoch 59/100
# 149/150 [============================>.] - ETA: 0s - loss: 0.0714 - categorical_accuracy: 0.9769
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0710 - categorical_accuracy: 0.9771 - val_loss: 1.1394 - val_categorical_accuracy: 0.7554 - lr: 5.0000e-04
# Epoch 60/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0083 - categorical_accuracy: 0.9983 - val_loss: 1.1344 - val_categorical_accuracy: 0.7613 - lr: 2.5000e-04
# Epoch 61/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 1.1468 - val_categorical_accuracy: 0.7633 - lr: 2.5000e-04
# Epoch 62/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 1.1577 - val_categorical_accuracy: 0.7625 - lr: 2.5000e-04

# %%
plot_network_history(network_history)

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
preds = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 5ms/step - loss: 2.8936 - categorical_accuracy: 0.5694
# 9/9 [==============================] - 0s 4ms/step

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)
y_true = np.argmax(Y_test, 1)

print("Test accuracy: %g" % (accuracy_score(y_true, y_pred)))
print("Precision", precision_score(y_true, y_pred, average="macro"))
print("Recall", recall_score(y_true, y_pred, average="macro"))
print("f1_score", f1_score(y_true, y_pred, average="macro"))
# Out:
# 9/9 [==============================] - 0s 4ms/step
# Test accuracy: 0.569444
# Precision 0.5571702676755869
# Recall 0.5509019162425258
# f1_score 0.5490115184060081

# %%
plt.figure(figsize=(8, 4))
conf = confusion_matrix(y_true, y_pred)
labels = emotion_list.values()
sns.heatmap(conf, annot=True, fmt="d", vmax=20, xticklabels=labels, yticklabels=labels)
plt.show()
