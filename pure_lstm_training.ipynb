# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import gc
import pickle
import sys

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from IPython.lib.display import Audio
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    BatchNormalization,
    Bidirectional,
    Conv1D,
    Dense,
    Dropout,
    Flatten,
    Input,
    MaxPool1D,
)
# Out:
# 2024-05-05 17:37:43.830704: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 17:37:43.859593: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 17:37:43.859618: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 17:37:43.859623: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 17:37:43.863972: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices("GPU")
print(gpus)
tf.config.set_logical_device_configuration(
    gpus[0],
    [tf.config.LogicalDeviceConfiguration(memory_limit=8000)],
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-05 17:37:45.484356: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.504438: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.504619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
emotion_list = {
    0: "neutral",
    1: "calm",
    2: "happy",
    3: "sad",
    4: "angry",
    5: "fearful",
    6: "disgusted",
    7: "surprised",
}

# %%
def plot_network_history(network_history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    axes[0].plot(network_history.history["loss"], label="Training Loss")
    axes[0].plot(network_history.history["val_loss"], label="Validation Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(network_history.history["categorical_accuracy"], label="Training Categorical Accuracy")
    axes[1].plot(network_history.history["val_categorical_accuracy"], label="Validation Categorical Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.show()

# %%
with open("./data/processed_data.pickle", "rb") as f:
    data = pickle.load(f)
X_train = data["X_train"]
X_test = data["X_test"]
Y_train = data["Y_train"]
Y_test = data["Y_test"]

# %%
X_train.shape
# Out:
# (12000, 40, 1)

# %%
print(gc.collect())
K.clear_session()

num_classes = len(Y_test[0])
model = Sequential()

layers = [
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(1024),
    Dense(num_classes, activation="softmax"),
]

model = tf.keras.Sequential(layers)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["categorical_accuracy"])

model.summary()
# Out:
# 47
# 2024-05-05 17:37:45.731253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.731511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.731633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.790893: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.791160: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.791292: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-05 17:37:45.791406: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8000 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2f:00.0, compute capability: 8.6
# 2024-05-05 17:37:45.803331: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:746] failed to allocate 7.81GiB (8388608000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1024)              4202496
#
#  dense (Dense)               (None, 8)                 8200
#
# =================================================================
# Total params: 4210696 (16.06 MB)
# Trainable params: 4210696 (16.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_categorical_accuracy", min_delta=0.00005, patience=10, restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_categorical_accuracy",
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)


network_history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[es, lr_scheduler],
)
# Out:
# Epoch 1/100
#   1/150 [..............................] - ETA: 3:28 - loss: 2.0858 - categorical_accuracy: 0.0469
# 2024-05-05 17:37:48.491273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2024-05-05 17:37:48.536151: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7605e8dbfe20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-05 17:37:48.536174: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-05-05 17:37:48.539144: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-05 17:37:48.599688: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 [==============================] - 4s 18ms/step - loss: 1.9310 - categorical_accuracy: 0.2453 - val_loss: 1.8183 - val_categorical_accuracy: 0.2879 - lr: 0.0010
# Epoch 2/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.7916 - categorical_accuracy: 0.2999 - val_loss: 1.7047 - val_categorical_accuracy: 0.3404 - lr: 0.0010
# Epoch 3/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.6934 - categorical_accuracy: 0.3464 - val_loss: 1.6634 - val_categorical_accuracy: 0.3542 - lr: 0.0010
# Epoch 4/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.6228 - categorical_accuracy: 0.3802 - val_loss: 1.6212 - val_categorical_accuracy: 0.3679 - lr: 0.0010
# Epoch 5/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.5672 - categorical_accuracy: 0.3995 - val_loss: 1.5581 - val_categorical_accuracy: 0.4075 - lr: 0.0010
# Epoch 6/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.5164 - categorical_accuracy: 0.4178 - val_loss: 1.5666 - val_categorical_accuracy: 0.3996 - lr: 0.0010
# Epoch 7/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4499 - categorical_accuracy: 0.4448 - val_loss: 1.4409 - val_categorical_accuracy: 0.4475 - lr: 0.0010
# Epoch 8/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3815 - categorical_accuracy: 0.4795 - val_loss: 1.3852 - val_categorical_accuracy: 0.4837 - lr: 0.0010
# Epoch 9/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.2871 - categorical_accuracy: 0.5127 - val_loss: 1.2716 - val_categorical_accuracy: 0.5238 - lr: 0.0010
# Epoch 10/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.1899 - categorical_accuracy: 0.5525 - val_loss: 1.2552 - val_categorical_accuracy: 0.5396 - lr: 0.0010
# Epoch 11/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.0961 - categorical_accuracy: 0.5946 - val_loss: 1.1728 - val_categorical_accuracy: 0.5683 - lr: 0.0010
# Epoch 12/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.9913 - categorical_accuracy: 0.6348 - val_loss: 1.1108 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 13/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.8959 - categorical_accuracy: 0.6734 - val_loss: 1.1401 - val_categorical_accuracy: 0.5913 - lr: 0.0010
# Epoch 14/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.8122 - categorical_accuracy: 0.7086 - val_loss: 0.9817 - val_categorical_accuracy: 0.6404 - lr: 0.0010
# Epoch 15/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.7013 - categorical_accuracy: 0.7474 - val_loss: 0.9773 - val_categorical_accuracy: 0.6592 - lr: 0.0010
# Epoch 16/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.6014 - categorical_accuracy: 0.7830 - val_loss: 0.9353 - val_categorical_accuracy: 0.6908 - lr: 0.0010
# Epoch 17/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.5281 - categorical_accuracy: 0.8150 - val_loss: 0.9815 - val_categorical_accuracy: 0.6708 - lr: 0.0010
# Epoch 18/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.4563 - categorical_accuracy: 0.8367 - val_loss: 0.9927 - val_categorical_accuracy: 0.6679 - lr: 0.0010
# Epoch 19/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.4193 - categorical_accuracy: 0.8514 - val_loss: 0.9155 - val_categorical_accuracy: 0.7042 - lr: 0.0010
# Epoch 20/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.3329 - categorical_accuracy: 0.8807 - val_loss: 0.8961 - val_categorical_accuracy: 0.7221 - lr: 0.0010
# Epoch 21/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2755 - categorical_accuracy: 0.9064 - val_loss: 0.8699 - val_categorical_accuracy: 0.7354 - lr: 0.0010
# Epoch 22/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2486 - categorical_accuracy: 0.9134 - val_loss: 0.8916 - val_categorical_accuracy: 0.7346 - lr: 0.0010
# Epoch 23/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2261 - categorical_accuracy: 0.9246 - val_loss: 0.8906 - val_categorical_accuracy: 0.7371 - lr: 0.0010
# Epoch 24/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1934 - categorical_accuracy: 0.9347 - val_loss: 0.8986 - val_categorical_accuracy: 0.7458 - lr: 0.0010
# Epoch 25/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1644 - categorical_accuracy: 0.9474 - val_loss: 0.8728 - val_categorical_accuracy: 0.7617 - lr: 0.0010
# Epoch 26/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1336 - categorical_accuracy: 0.9577 - val_loss: 0.9845 - val_categorical_accuracy: 0.7475 - lr: 0.0010
# Epoch 27/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1144 - categorical_accuracy: 0.9650 - val_loss: 0.9731 - val_categorical_accuracy: 0.7521 - lr: 0.0010
# Epoch 28/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1453 - categorical_accuracy: 0.9523 - val_loss: 1.0077 - val_categorical_accuracy: 0.7496 - lr: 0.0010
# Epoch 29/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1329 - categorical_accuracy: 0.9557 - val_loss: 1.0068 - val_categorical_accuracy: 0.7371 - lr: 0.0010
# Epoch 30/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0851 - categorical_accuracy: 0.9740 - val_loss: 0.9281 - val_categorical_accuracy: 0.7642 - lr: 0.0010
# Epoch 31/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0882 - categorical_accuracy: 0.9751 - val_loss: 1.0331 - val_categorical_accuracy: 0.7475 - lr: 0.0010
# Epoch 32/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0796 - categorical_accuracy: 0.9768 - val_loss: 1.0215 - val_categorical_accuracy: 0.7483 - lr: 0.0010
# Epoch 33/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1107 - categorical_accuracy: 0.9652 - val_loss: 1.0867 - val_categorical_accuracy: 0.7317 - lr: 0.0010
# Epoch 34/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1255 - categorical_accuracy: 0.9613 - val_loss: 1.0293 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 35/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0537 - categorical_accuracy: 0.9850 - val_loss: 0.9934 - val_categorical_accuracy: 0.7583 - lr: 0.0010
# Epoch 36/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0588 - categorical_accuracy: 0.9829 - val_loss: 1.0235 - val_categorical_accuracy: 0.7650 - lr: 0.0010
# Epoch 37/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0394 - categorical_accuracy: 0.9886 - val_loss: 0.9886 - val_categorical_accuracy: 0.7671 - lr: 0.0010
# Epoch 38/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0619 - categorical_accuracy: 0.9816 - val_loss: 1.1340 - val_categorical_accuracy: 0.7508 - lr: 0.0010
# Epoch 39/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1059 - categorical_accuracy: 0.9684 - val_loss: 1.0891 - val_categorical_accuracy: 0.7554 - lr: 0.0010
# Epoch 40/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0546 - categorical_accuracy: 0.9845 - val_loss: 1.0736 - val_categorical_accuracy: 0.7517 - lr: 0.0010
# Epoch 41/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0479 - categorical_accuracy: 0.9867 - val_loss: 1.0489 - val_categorical_accuracy: 0.7625 - lr: 0.0010
# Epoch 42/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0693 - categorical_accuracy: 0.9807 - val_loss: 1.1458 - val_categorical_accuracy: 0.7433 - lr: 0.0010
# Epoch 43/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0505 - categorical_accuracy: 0.9848 - val_loss: 1.0837 - val_categorical_accuracy: 0.7638 - lr: 0.0010
# Epoch 44/100
# 149/150 [============================>.] - ETA: 0s - loss: 0.0354 - categorical_accuracy: 0.9898
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0370 - categorical_accuracy: 0.9893 - val_loss: 1.1098 - val_categorical_accuracy: 0.7550 - lr: 0.0010
# Epoch 45/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0266 - categorical_accuracy: 0.9932 - val_loss: 1.0309 - val_categorical_accuracy: 0.7725 - lr: 5.0000e-04
# Epoch 46/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0048 - categorical_accuracy: 0.9993 - val_loss: 1.0365 - val_categorical_accuracy: 0.7746 - lr: 5.0000e-04
# Epoch 47/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0017 - categorical_accuracy: 0.9999 - val_loss: 1.0508 - val_categorical_accuracy: 0.7754 - lr: 5.0000e-04
# Epoch 48/100
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 1.0654 - val_categorical_accuracy: 0.7767 - lr: 5.0000e-04
# Epoch 49/100
# 150/150 [==============================] - 2s 15ms/step - loss: 9.4672e-04 - categorical_accuracy: 1.0000 - val_loss: 1.0757 - val_categorical_accuracy: 0.7758 - lr: 5.0000e-04
# Epoch 50/100
# 150/150 [==============================] - 2s 15ms/step - loss: 7.8074e-04 - categorical_accuracy: 1.0000 - val_loss: 1.0872 - val_categorical_accuracy: 0.7767 - lr: 5.0000e-04
# Epoch 51/100
# 150/150 [==============================] - 2s 15ms/step - loss: 6.5107e-04 - categorical_accuracy: 1.0000 - val_loss: 1.0971 - val_categorical_accuracy: 0.7758 - lr: 5.0000e-04
# Epoch 52/100
# 150/150 [==============================] - 2s 15ms/step - loss: 5.5649e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1063 - val_categorical_accuracy: 0.7779 - lr: 5.0000e-04
# Epoch 53/100
# 150/150 [==============================] - 2s 15ms/step - loss: 4.8194e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1154 - val_categorical_accuracy: 0.7796 - lr: 5.0000e-04
# Epoch 54/100
# 150/150 [==============================] - 2s 15ms/step - loss: 4.2247e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1242 - val_categorical_accuracy: 0.7804 - lr: 5.0000e-04
# Epoch 55/100
# 150/150 [==============================] - 2s 15ms/step - loss: 3.7427e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1330 - val_categorical_accuracy: 0.7825 - lr: 5.0000e-04
# Epoch 56/100
# 150/150 [==============================] - 2s 15ms/step - loss: 3.3256e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1414 - val_categorical_accuracy: 0.7825 - lr: 5.0000e-04
# Epoch 57/100
# 150/150 [==============================] - 2s 15ms/step - loss: 2.9714e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1496 - val_categorical_accuracy: 0.7833 - lr: 5.0000e-04
# Epoch 58/100
# 150/150 [==============================] - 2s 15ms/step - loss: 2.6703e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1576 - val_categorical_accuracy: 0.7825 - lr: 5.0000e-04
# Epoch 59/100
# 150/150 [==============================] - 2s 15ms/step - loss: 2.4066e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1657 - val_categorical_accuracy: 0.7817 - lr: 5.0000e-04
# Epoch 60/100
# 150/150 [==============================] - 2s 15ms/step - loss: 2.1734e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1734 - val_categorical_accuracy: 0.7817 - lr: 5.0000e-04
# Epoch 61/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.9684e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1808 - val_categorical_accuracy: 0.7821 - lr: 5.0000e-04
# Epoch 62/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.7868e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1887 - val_categorical_accuracy: 0.7817 - lr: 5.0000e-04
# Epoch 63/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.6250e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1961 - val_categorical_accuracy: 0.7808 - lr: 5.0000e-04
# Epoch 64/100
# 149/150 [============================>.] - ETA: 0s - loss: 1.4812e-04 - categorical_accuracy: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4797e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2038 - val_categorical_accuracy: 0.7800 - lr: 5.0000e-04
# Epoch 65/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3602e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2077 - val_categorical_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 66/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.2991e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2116 - val_categorical_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 67/100
# 150/150 [==============================] - 2s 15ms/step - loss: 1.2389e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2158 - val_categorical_accuracy: 0.7804 - lr: 2.5000e-04

# %%
plot_network_history(network_history)

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
preds = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 5ms/step - loss: 3.2663 - categorical_accuracy: 0.5000
# 9/9 [==============================] - 0s 4ms/step

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)
y_true = np.argmax(Y_test, 1)

print("Test accuracy: %g" % (accuracy_score(y_true, y_pred)))
print("Precision", precision_score(y_true, y_pred, average="macro"))
print("Recall", recall_score(y_true, y_pred, average="macro"))
print("f1_score", f1_score(y_true, y_pred, average="macro"))
# Out:
# 9/9 [==============================] - 0s 4ms/step
# Test accuracy: 0.5
# Precision 0.5001338959352744
# Recall 0.4914000618224497
# f1_score 0.4934915254449884

# %%
plt.figure(figsize=(8, 4))
conf = confusion_matrix(y_true, y_pred)
labels = emotion_list.values()
sns.heatmap(conf, annot=True, fmt="d", vmax=20, xticklabels=labels, yticklabels=labels)
plt.show()
