# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import gc
import pickle
import sys

import librosa
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from audiomentations import AddGaussianNoise, Compose, PitchShift, Shift, TimeStretch
from IPython.lib.display import Audio
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    Bidirectional,
    Dense,
    Dropout,
    Input,
    Conv1D,
    BatchNormalization
)
from tensorflow.keras.utils import to_categorical

# %%
gpus = tf.config.list_physical_devices("GPU")
print(gpus)
tf.config.set_logical_device_configuration(
    gpus[0],
    [tf.config.LogicalDeviceConfiguration(memory_limit=8000)],
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-02 10:57:33.754289: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-02 10:57:33.902061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-02 10:57:33.902346: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
emotion_list = {
    0: "neutral",
    1: "calm",
    2: "happy",
    3: "sad",
    4: "angry",
    5: "fearful",
    6: "disgusted",
    7: "surprised",
}
RAV = "data/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
dir_list = os.listdir(RAV)
paths = []
for dir in dir_list:
    files = os.listdir(RAV + dir)
    for file in files:
        paths.append(RAV + dir + "/" + file)

path_train, path_test = train_test_split(paths, test_size=0.2)

# %%
augment = Compose(
    [
        AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.002, p=0.5),  # p = 0.5
        TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
        PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
        Shift(p=0.5),
    ]
)

# %%
def get_label(path, emotion_list):
    fileName = os.path.basename(path)
    parts = fileName.split(".")[0].split("-")
    return int(parts[2]) - 1


def process_test_audios(paths):
    batch_features, batch_labels = [], []
    for path in paths:
        audio, sample_rate = librosa.load(path)
        augmented_audio = augment(samples=audio, sample_rate=sample_rate)
        batch_features.append(augmented_audio)
        batch_labels.append(get_label(path, emotion_list))
    return batch_features, batch_labels


def audio_generator(file_paths, batch_size):
    while True:
        batch_paths = np.random.choice(a=file_paths, size=batch_size)
        batch_features, batch_labels = [], []

        for path in batch_paths:
            audio, sample_rate = librosa.load(path)
            augmented_audio = augment(samples=audio, sample_rate=sample_rate)
            batch_features.append(augmented_audio)
            batch_labels.append(get_label(path, emotion_list))

        yield batch_features, batch_labels


def extract_mfcc(audio):
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40).T, axis=0)
    return mfccs


def plot_network_history(network_history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    axes[0].plot(network_history.history["loss"], label="Training Loss")
    axes[0].plot(network_history.history["val_loss"], label="Validation Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(network_history.history["accuracy"], label="Training Accuracy")
    axes[1].plot(network_history.history["val_accuracy"], label="Validation Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.show()

# %%
# X_test, Y_test = process_test_audios(path_test)

# batch_size = 24
# gen = audio_generator(file_paths=path_train, batch_size=batch_size)
# X_train, Y_train = [], []
# for i in range(150):
#     batch_data, batch_labels = next(gen)
#     X_train += batch_data
#     Y_train += batch_labels

# len(X_train), len(Y_train)

# %%
# X_train = np.array([extract_mfcc(audio) for audio in X_train])
# X_test = np.array([extract_mfcc(audio) for audio in X_test])
# X_train = np.expand_dims(X_train, -1)
# X_test = np.expand_dims(X_test, -1)

# Y_train, Y_test = to_categorical(Y_train), to_categorical(Y_test)

# %%
# data = {"X_train": X_train, "X_test": X_test, "Y_train": Y_train, "Y_test": Y_test}
# with open("./data/processed_data.pickle", "wb") as f:
#     pickle.dump(data, f)

# %%
with open("./data/processed_data.pickle", "rb") as f:
    data = pickle.load(f)
X_train = data["X_train"]
X_test = data["X_test"]
Y_train = data["Y_train"]
Y_test = data["Y_test"]

# %%
X_train.shape
# Out:
# (3600, 40, 1)

# %%
print(gc.collect())
K.clear_session()

num_classes = len(Y_test[0])
model = Sequential()

layers = [
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    
    Conv1D(filters=50, kernel_size=3),
    BatchNormalization(),
    Dropout(0.2),

    Conv1D(filters=100, kernel_size=3),
    BatchNormalization(),
    Dropout(0.2),

    Conv1D(filters=200, kernel_size=3),
    BatchNormalization(),
    Dropout(0.2),
    
    LSTM(1024),
    Dense(num_classes, activation="softmax"),
]

model = tf.keras.Sequential(layers)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.summary()
# Out:
# 46173
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 38, 50)            200
#
#  batch_normalization (Batch  (None, 38, 50)            200
#  Normalization)
#
#  dropout (Dropout)           (None, 38, 50)            0
#
#  conv1d_1 (Conv1D)           (None, 36, 100)           15100
#
#  batch_normalization_1 (Bat  (None, 36, 100)           400
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 36, 100)           0
#
#  conv1d_2 (Conv1D)           (None, 34, 200)           60200
#
#  batch_normalization_2 (Bat  (None, 34, 200)           800
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 34, 200)           0
#
#  lstm (LSTM)                 (None, 1024)              5017600
#
#  dense (Dense)               (None, 8)                 8200
#
# =================================================================
# Total params: 5102700 (19.47 MB)
# Trainable params: 5102000 (19.46 MB)
# Non-trainable params: 700 (2.73 KB)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", min_delta=0.01, patience=5, restore_best_weights=True
)
network_history = model.fit(
    X_train, Y_train, epochs=100, validation_split=0.2, callbacks=[es]
)
# Out:
# Epoch 1/100
# 90/90 [==============================] - 4s 18ms/step - loss: 2.0682 - accuracy: 0.1660 - val_loss: 2.0243 - val_accuracy: 0.1861
# Epoch 2/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.9942 - accuracy: 0.2118 - val_loss: 2.0111 - val_accuracy: 0.1806
# Epoch 3/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.9269 - accuracy: 0.2330 - val_loss: 1.9191 - val_accuracy: 0.2639
# Epoch 4/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.8625 - accuracy: 0.2764 - val_loss: 1.7991 - val_accuracy: 0.2931
# Epoch 5/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.8214 - accuracy: 0.2892 - val_loss: 1.8473 - val_accuracy: 0.2903
# Epoch 6/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.7440 - accuracy: 0.3247 - val_loss: 1.7135 - val_accuracy: 0.3125
# Epoch 7/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.6916 - accuracy: 0.3431 - val_loss: 1.6798 - val_accuracy: 0.3306
# Epoch 8/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.6096 - accuracy: 0.3931 - val_loss: 1.7164 - val_accuracy: 0.3389
# Epoch 9/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.5284 - accuracy: 0.4278 - val_loss: 1.6434 - val_accuracy: 0.3639
# Epoch 10/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.4794 - accuracy: 0.4431 - val_loss: 1.6330 - val_accuracy: 0.3889
# Epoch 11/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.3621 - accuracy: 0.4844 - val_loss: 1.5841 - val_accuracy: 0.3958
# Epoch 12/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.2721 - accuracy: 0.5385 - val_loss: 1.5067 - val_accuracy: 0.4542
# Epoch 13/100
# 90/90 [==============================] - 1s 12ms/step - loss: 1.0850 - accuracy: 0.6045 - val_loss: 1.4851 - val_accuracy: 0.4694
# Epoch 14/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.9801 - accuracy: 0.6507 - val_loss: 1.4441 - val_accuracy: 0.5056
# Epoch 15/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.8403 - accuracy: 0.7035 - val_loss: 1.4768 - val_accuracy: 0.4944
# Epoch 16/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.7336 - accuracy: 0.7462 - val_loss: 1.4643 - val_accuracy: 0.5083
# Epoch 17/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.6076 - accuracy: 0.7986 - val_loss: 1.4984 - val_accuracy: 0.5125
# Epoch 18/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.4576 - accuracy: 0.8549 - val_loss: 1.3921 - val_accuracy: 0.5514
# Epoch 19/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3455 - accuracy: 0.8938 - val_loss: 1.5128 - val_accuracy: 0.5500
# Epoch 20/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3049 - accuracy: 0.9094 - val_loss: 1.6151 - val_accuracy: 0.5583
# Epoch 21/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2504 - accuracy: 0.9240 - val_loss: 1.6568 - val_accuracy: 0.5542
# Epoch 22/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1974 - accuracy: 0.9448 - val_loss: 1.6482 - val_accuracy: 0.5431
# Epoch 23/100
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1444 - accuracy: 0.9604 - val_loss: 1.6573 - val_accuracy: 0.5583

# %%
plot_network_history(network_history)

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
preds = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0449 - accuracy: 0.4271
# 9/9 [==============================] - 0s 4ms/step

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)
y_true = np.argmax(Y_test, 1)

print("Test accuracy: %g" % (accuracy_score(y_true, y_pred)))
print("Precision", precision_score(y_true, y_pred, average="macro"))
print("Recall", recall_score(y_true, y_pred, average="macro"))
print("f1_score", f1_score(y_true, y_pred, average="macro"))
# Out:
# 9/9 [==============================] - 0s 4ms/step
# Test accuracy: 0.427083
# Precision 0.4038542823099315
# Recall 0.4042153498675238
# f1_score 0.40098242890034236

# %%
plt.figure(figsize=(8, 4))
conf = confusion_matrix(y_true, y_pred)
labels = emotion_list.values()
sns.heatmap(conf, annot=True, fmt="d", vmax=20, xticklabels=labels, yticklabels=labels)
plt.show()
